# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm, trange

# %%
# %load_ext autoreload
# %autoreload 2

from bs_helpers import *
from bs_gameclass import *
from bsp_helpers import *
from utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def batchgen(size=32):
    while True:
        xs, ys = [], []
        for _ in range(size):
            hist, target, shipnum = play(np.random.randint(SX**2))
            xs.append(encode(hist, shipnum))
            ys.append(target)
        yield np.array(xs), np.array(ys)

# %%
bg = batchgen()
xs, ys = next(bg)

# %%
xs.shape
# Out:
# (32, 101, 100)

# %%
from bsp_transformer import *
from torch_optimizer import Lookahead, Yogi
net = Net()
#net.optim = torch.optim.Adam(lr=1e-3, params=net.parameters())
net.optim = Lookahead(Yogi(lr=3e-3, betas=(0.9, 0.98), params=net.parameters()))
net.losses = []
net.iters = 0

# %%
net.load_state_dict(torch.load('data/bsp_transformer_071223.dat'))
# Out:
# <All keys matched successfully>

# %%
def loss():
    xs, ys = next(bg)
    xs, ys = np2t(xs, ys)
    yp = net(xs)
    yp = yp.view(-1, 3)
    ys = ys.view(-1)
    loss = F.nll_loss(torch.log(yp+1e-12), ys.long())
    return loss

loss()
# Out:
# tensor(0.1238, device='cuda:0', grad_fn=<NllLossBackward0>)

# %%
def lrscheduler(i):
    warmupsteps = 200
    maxlr = 3e-3
    lr = min(maxlr, i/warmupsteps*maxlr)
    for g in net.optim.param_groups:
        g['lr'] = lr

# %%
BCE = nn.BCELoss()
losses = []
bg = batchgen()

for k in trange(999999):

    lrscheduler(net.iters)
    l = loss()
    l.backward()
    net.optim.step()
    net.zero_grad()
    #print(loss)
    losses.append(l.item())

    if k%200 == 0:
        ##xs, ys, yp = t2np(xs, ys, yp)
        net.losses.append((net.iters, np.mean(losses)))
        losses = []
        plt.plot(*zip(*net.losses))
        #plt.ylim([0,0.1])
        plt.grid()
        plt.show()
        torch.save(net.state_dict(), 'data/bsp_transformer_071223.dat')
        
    net.iters += 1
# Out:
#   0%|          | 0/999999 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 8
#       5 for k in trange(999999):
#       7     lrscheduler(net.iters)
# ----> 8     l = loss()
#       9     l.backward()
#      10     net.optim.step()
#
# Cell In[15], line 2, in loss()
#       1 def loss():
# ----> 2     xs, ys = next(bg)
#       3     xs, ys = np2t(xs, ys)
#       4     yp = net(xs)
#
# Cell In[9], line 6, in batchgen(size)
#       4 for _ in range(size):
#       5     hist, target, shipnum = play(np.random.randint(SX**2))
# ----> 6     xs.append(encode(hist, shipnum))
#       7     ys.append(target)
#       8 yield np.array(xs), np.array(ys)
#
# File D:\WPy64-31150\notebooks\battle-ships\bsp_helpers.py:141, in encode(hist, shipnum)
#     139 #x = np.zeros((SX**2, 2*SX+2+8))
#     140 NBUFF = 100
# --> 141 x = np.zeros((1+SX**2, NBUFF))
#     142 x[0, :6*(NSHIPS+1)] = encode_shipnum(shipnum)
#     144 for k in range(len(hist)):
#
# KeyboardInterrupt:

# %%
def show_hist(hist, shipnum, ax):
    lines = []
    for tpl in hist:
        tpl = (tpl[0], int(tpl[1]), tpl[2])
        line = f'shot at ({tpl[0][0]}, {tpl[0][1]})'
        if tpl[1] and tpl[2]: line += ', ship sunk!'
        elif tpl[1]: line += ', ship hit'
        #line = repr(tpl)
        lines.append(line)
    if len(lines) > 10:
        lines = lines[-10:]
        lines[0] = '...'
    lines = ['Ship numbers: ' + repr(list(shipnum[2:]))] + lines
    text = '\n'.join(lines)
    ax.text(0, 0.5, text, size=12, va='top')
    plt.imshow(np.ones_like(det), vmin=0., vmax=1., cmap='gray')
    ax.axis('off')

# %%
from vidcapture import vidcapture
net.eval()
det = np.zeros((10,10))
shipnum = np.array([0, 0, 0, 0, 2, 4])
sea, ships = create_sea_ships(shipnum, seed=1000)
i,j = [],[]
##vc = vidcapture('F:/$Daten/vidcaptures/battleship transformer3/frame%05d.png')
moves = []
hits = []
sunken = []
hist = []
while True:
    yp = t2np(net(np2t([encode(hist, shipnum)]))).reshape((10,10,3))
    prob = yp[:,:,1] + yp[:,:,2]
    ##prob[det > 0] = 0
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 8))
    ax1.title.set_text('Map')
    ax2.title.set_text('Neural Network prediction')
    ax3.title.set_text('Game History / Network Input')
    ax1.axis('off')
    ##plot_sea(sea, det, ax1)
    plot_ships(ships, det, ax1)
    ax1.scatter(j, i, c='black', alpha=1, s=150)
    ax2.axis('off')
    ax2.imshow((prob*(1-det)), vmin=0., vmax=.5)
    show_hist(hist, shipnum, ax3)
    ##vc.capture()
    plt.show()
    
    if np.sum(det*sea) >= np.sum(sea): break
        
    # Welchen Detektieren??
    prob2 = prob  ##
    prob2[det > 0] = 0
    m = prob2.argmax()
    i, j = m//10, m%10
    det[i,j] = 1.
    
    # history aufzeichnen
    moves.append((i,j))
    hits.append(sea[i,j])
    sunken.append(sinksShip(ships, det, (i,j)))
    hist = list(zip(moves, hits, sunken))

# %%
repr(shipnum[2:])

# %%
# Viele Spiele spielen und score sehen
from bs_gameclass import *
shipnum = (0, 0, 4, 3, 2, 1)

rs = []
for _ in trange(100):
    s = GameState()
    h, ships = create_sea_ships(shipnum)
    r = 0
    moves = []
    rewards = []
    sunken = []
    hist = []
    while not GameClass.getEnded(s):
        yp = t2np(net(np2t([encode(hist, shipnum)]))).reshape((10,10,3))
        prob = yp[:,:,1] + yp[:,:,2]
        prob[s.det==1] = 0
        ij = argmax2d(prob)
        s = GameClass.getNextState(s, ij, h)
        r += h[ij]*np.mean(1-s.det)
        moves.append((ij))
        rewards.append(h[ij])
        sn = sinksShip(ships, s.det, ij)
        sunken.append(sn)
        hist = list(zip(moves, rewards, sunken))
    rs.append(r)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 15
#      13 hist = []
#      14 while not GameClass.getEnded(s):
# ---> 15     prob = t2np(net(np2t([encode(hist, shipnum)]))).reshape((10,10))
#      16     prob[s.det==1] = 0
#      17     ij = argmax2d(prob)
#
# ValueError: cannot reshape array of size 300 into shape (10,10)

# %%
np.mean(rs)
