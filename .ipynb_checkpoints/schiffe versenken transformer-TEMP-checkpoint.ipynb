# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm, trange

# %%
# %load_ext autoreload
# %autoreload 2

from bs_helpers import *
from bs_gameclass import *
from utils import *

SX = 10
NSHIPS = 10

# %%
def create_sea_ships(seed=None): # diese funktion ist anders als die bei unet!!
    'Creates a sea with random ships on it'
    rng = random.Random(seed)
    sea = np.zeros((SX,SX))
    ships = np.zeros((SX,SX,NSHIPS)) # extra information which kind of ship is where
    k = 0
    for l in [5,4,3,2]: # Länge
        n = 6-l # Anzahl
        for _ in range(n):
            # Boot mit Länge l platzieren
            while True:
                t = rng.random() < 0.5
                if t:
                    sea = sea.T # Transponieren
                    ships = ships.transpose(1,0,2)
                px = rng.randint(0, 10-l)
                py = rng.randint(0, 9)
                if sum(sea[px:px+l,py]) > 0:
                    continue
                sea[px:px+l, py] = 1
                ships[px:px+l, py, k] = 1
                if t:
                    sea = sea.T # Transponieren
                    ships = ships.transpose(1,0,2)
                k += 1
                break
    return sea, ships

# %%
@njit(cache=True)
def njit_create_sea_ships(seed=None): # diese funktion ist anders als die bei unet!!
    'Creates a sea with random ships on it'
    sea = np.zeros((10,10))
    ships = np.zeros((10,10,10)) # extra information which kind of ship is where
    k = 0
    for l in [5,4,3,2]: # Länge
        n = 6-l # Anzahl
        for _ in range(n):
            # Boot mit Länge l platzieren
            while True:
                t = np.random.rand() < 0.5
                if t:
                    sea = sea.T # Transponieren
                    ships = ships.transpose(1,0,2)
                px = np.random.randint(0, 11-l)
                py = np.random.randint(0, 10)
                if sum(sea[px:px+l,py]) > 0:
                    continue
                sea[px:px+l, py] = 1
                ships[px:px+l, py, k] = 1
                if t:
                    sea = sea.T # Transponieren
                    ships = ships.transpose(1,0,2)
                k += 1
                break
    return sea, ships

# %%
def visualize(sea, detection):
    'Erstellt eine Veranschaulichung, 0 bzw. 4 sind detektiertes Wasser bzw. Schiff, 1 und 2 sind undetektiert.'
    return sea + sea*detection + 1 - ((1-sea)*detection)


def plot_sea(sea, det, ax=None):
    if ax is None: ax = plt.gca()
    #ax.imshow(visualize(sea, det), vmin=-2, cmap='plasma')
    ax.imshow(visualize(sea, det), vmin=-1, vmax=3.15, cmap='cividis')
    for k in range(NSHIPS)
    ax.axis('off')

# %%
sea, ships = create_sea_ships()
plot_sea(sea, np.random.rand(SX, SX)<.5)

# %%
@njit(cache=True)
def play():
    'Plays a game and returns the game history and the sea'
    sea, ships = njit_create_sea_ships()
    det = np.zeros_like(sea)
    moves = []
    rewards = []
    sunken = []
    for _ in range(SX**2):
        vms = [ (i,j) for i in range(SX) for j in range(SY) if (1-det[i,j]) ]
        k = np.random.randint(len(vms))
        ij = vms[k]
        det[ij] = 1
        moves.append(ij)
        rewards.append(sea[ij])
        sn = 0
        for l in range(NSHIPS):
            if ships[ij][l]:
                if np.sum(ships[:,:,l] * (1-det)) == 0:
                    sn = 1
        sunken.append(sn)
    return list(zip(moves, rewards, sunken)), sea


def encode(hist):
    'Encodes the visible information to an input to the neural network'
    def bits(k):
        return [ float((k>>i)&1) for i in range(8) ]
    
    x = np.zeros((SX**2, 2*SX+2+8))
    for k in range(len(hist)):
        (i,j),r,sn = hist[k]
        x[k, i] = 1
        x[k, SX+j] = 1
        x[k, 2*SX] = r
        x[k, 2*SX+1] = sn
        x[k, 2*SX+2:] = np.asarray(bits(k))
    return x
    

def batchgen(size=32):
    while True:
        xs, ys = [], []
        for _ in range(size):
            hist, sea = play()
            hist = hist[:np.random.randint(100)]
            xs.append(encode(hist))
            ys.append(sea)
        yield np.array(xs), np.array(ys)

# %%
bg = batchgen()
xs, ys = next(bg)

# %%
xs.shape
# Out:
# (32, 100, 30)

# %%
from bs_transformer import *
from torch_optimizer import Lookahead, Yogi
net = Net()
#net.optim = torch.optim.Adam(lr=1e-3, params=net.parameters())
net.optim = Lookahead(Yogi(lr=3e-3, betas=(0.9, 0.98), params=net.parameters()))
net.losses = []
net.iters = 0

# %%
net.load_state_dict(torch.load('data/transformer3.dat'))
# Out:
# <All keys matched successfully>

# %%
def Loss():
    xs, ys = next(bg)
    xs, ys = np2t(xs, ys)
    yp = net(xs)
    loss = BCE(yp.view(-1), ys.view(-1))
    return loss

# %%
def lrscheduler(i):
    warmupsteps = 200
    maxlr = 3e-3
    lr = min(maxlr, i/warmupsteps*maxlr)
    for g in net.optim.param_groups:
        g['lr'] = lr

# %%
BCE = nn.BCELoss()
losses = []
bg = batchgen()

for k in trange(999999):

    lrscheduler(net.iters)
    loss = Loss()
    loss.backward()
    net.optim.step()
    net.zero_grad()
    #print(loss)
    losses.append(loss.item())

    if k%200 == 0:
        ##xs, ys, yp = t2np(xs, ys, yp)
        net.losses.append((net.iters, np.mean(losses)))
        losses = []
        plt.plot(*zip(*net.losses))
        #plt.ylim([0,0.1])
        plt.grid()
        plt.show()
        
    net.iters += 1
# Out:
#   0%|          | 0/999999 [00:00<?, ?it/s]

# %%
torch.save(net.state_dict(), 'data/transformer3.dat')

# %%
from vidcapture import vidcapture
det = np.zeros((10,10))
sea, ships = create_sea_ships(100)
i,j = [],[]
vc = vidcapture('F:/$Daten/vidcaptures/battleships transformer/frame%05d.png')
moves = []
rewards = []
sunken = []
hist = []
while True:
    prob = t2np(net(np2t([encode(hist)]))).reshape((10,10))
    ##prob[det > 0] = 0
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))
    ax1.title.set_text('Map')
    ax2.title.set_text('Neural Network prediction')
    ax1.axis('off')
    plot_sea(sea, det, ax1)
    ax1.scatter(j, i, c='black', alpha=1, s=150)
    ax2.axis('off')
    ax2.imshow(prob*(1-det))
    vc.capture()
    plt.show()
    
    if np.sum(det*sea) >= np.sum(sea): break
        
    # Welchen Detektieren??
    prob2 = prob  ##
    prob2[det > 0] = 0
    m = prob2.argmax()
    i, j = m//10, m%10
    det[i,j] = 1.
    
    # history aufzeichnen
    moves.append((i,j))
    rewards.append(sea[i,j])
    sn = 0
    for l in range(NSHIPS):
        if ships[i,j][l]:
            if np.sum(ships[:,:,l] * (1-det)) == 0:
                sn = 1
    sunken.append(sn)
    hist = list(zip(moves, rewards, sunken))

# %%
# Viele Spiele spielen und score sehen
from bs_gameclass import *

rs = []
for _ in trange(100):
    s = GameState()
    h, ships = create_sea_ships()
    r = 0
    moves = []
    rewards = []
    sunken = []
    hist = []
    while not GameClass.getEnded(s):
        prob = t2np(net(np2t([encode(hist)]))).reshape((10,10))
        prob[s.det==1] = 0
        ij = argmax2d(prob)
        s = GameClass.getNextState(s, ij, h)
        r += h[ij]*np.mean(1-s.det)
        moves.append((ij))
        rewards.append(h[ij])
        sn = 0
        for l in range(NSHIPS):
            if ships[ij][l]:
                if np.sum(ships[:,:,l] * (1-s.det)) == 0:
                    sn = 1
        sunken.append(sn)
        hist = list(zip(moves, rewards, sunken))
    rs.append(r)

# %%
np.mean(rs)
